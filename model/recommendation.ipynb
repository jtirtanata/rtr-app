# %% [markdown]
# ## Recommendation App
# - [Importing libraries](#import)
# - [Fetching data frames and models](#fetching)
# ### [Normalization](#norm)
# ### [Recommendation walkthrough](#walkthrough)
# - [finding cluster function](#findingCluster)
# - [combining features](#combination)

# %% [markdown]
# <a id="import"></a>
# ### Imports

# %%
import pandas as pd
import pickle
import numpy as np
from sklearn.metrics import pairwise_distances

from pymongo import MongoClient

# %%
client = MongoClient('ec2-34-198-179-91.compute-1.amazonaws.com', 27017)
db = client.fletcher
dress_col = db.rtr_dresses
cur_dress = dress_col.find()

# %% [markdown]
# <a id="fetching"></a>
# ### Fetching the related data frames and models

# %%
df_general = pd.read_csv('../data/dress_features.csv', index_col=0)

# %%
df_body = pd.read_csv('../data/dress_features_bt.csv', index_col=0)

# %% [markdown]
# <a id="norm"></a>
# ### Normalization
# - Normalizing df_body is not needed. We need to simply list the dresses in order of the score.
# - For df_general, we need to normalize it per column. Make all columns go from 0 to 1.

# %%
def normalize(df):
    mapping = {}
    df_norm = df.copy()
    for col in df.columns:
        max = df[col].max()
        min = df[col].min()
        col_range = max - min
        df_norm[col] = (df[col] - min) / col_range
        mapping[col] = {'min' : min, 'col_range' : col_range}
    return df_norm, mapping

# %%
df_norm, mapping = normalize(df_general)

# %%
df_norm.head(10)
# Out:
#                                                         back       bra  \
# url
# https://www.renttherunway.com/shop/designers/al...  0.490403  0.367929
# https://www.renttherunway.com/shop/designers/al...  0.580244  0.270334
# https://www.renttherunway.com/shop/designers/ba...  0.611154  0.350834
# https://www.renttherunway.com/shop/designers/ba...  0.525334  0.389743
# https://www.renttherunway.com/shop/designers/ba...  0.567095  0.497440
# https://www.renttherunway.com/shop/designers/ba...  0.494343  0.439424
# https://www.renttherunway.com/shop/designers/ba...  0.559083  0.483927
# https://www.renttherunway.com/shop/designers/ba...  0.465413  0.404489
# https://www.renttherunway.com/shop/designers/ba...  0.489033  0.428355
# https://www.renttherunway.com/shop/designers/ba...  0.419384  0.496229
#
#                                                        color  material  \
# url
# https://www.renttherunway.com/shop/designers/al...  0.681637  0.397041
# https://www.renttherunway.com/shop/designers/al...  0.574516  0.361258
# https://www.renttherunway.com/shop/designers/ba...  0.596360  0.329520
# https://www.renttherunway.com/shop/designers/ba...  0.539367  0.338634
# https://www.renttherunway.com/shop/designers/ba...  0.644953  0.284895
# https://www.renttherunway.com/shop/designers/ba...  0.560989  0.302429
# https://www.renttherunway.com/shop/designers/ba...  0.325848  0.297377
# https://www.renttherunway.com/shop/designers/ba...  0.571204  0.421545
# https://www.renttherunway.com/shop/designers/ba...  0.580295  0.264312
# https://www.renttherunway.com/shop/designers/ba...  0.648871  0.363530
#
#                                                     sequins_polar  \
# url
# https://www.renttherunway.com/shop/designers/al...       0.265116
# https://www.renttherunway.com/shop/designers/al...       0.381998
# https://www.renttherunway.com/shop/designers/ba...       0.310286
# https://www.renttherunway.com/shop/designers/ba...       0.459688
# https://www.renttherunway.com/shop/designers/ba...       0.350572
# https://www.renttherunway.com/shop/designers/ba...       0.319496
# https://www.renttherunway.com/shop/designers/ba...       0.413565
# https://www.renttherunway.com/shop/designers/ba...       0.238415
# https://www.renttherunway.com/shop/designers/ba...       0.316740
# https://www.renttherunway.com/shop/designers/ba...       0.296689
#
#                                                     sequins_unpolar   wedding  \
# url
# https://www.renttherunway.com/shop/designers/al...         0.015512  0.297983
# https://www.renttherunway.com/shop/designers/al...         0.012793  0.596208
# https://www.renttherunway.com/shop/designers/ba...         0.281476  0.302956
# https://www.renttherunway.com/shop/designers/ba...         0.000890  0.351250
# https://www.renttherunway.com/shop/designers/ba...         0.575796  0.097662
# https://www.renttherunway.com/shop/designers/ba...         0.471619  0.296763
# https://www.renttherunway.com/shop/designers/ba...         0.030063  0.238648
# https://www.renttherunway.com/shop/designers/ba...         0.346876  0.423181
# https://www.renttherunway.com/shop/designers/ba...         0.301871  0.237510
# https://www.renttherunway.com/shop/designers/ba...         0.562428  0.345795
#
#                                                      pockets
# url
# https://www.renttherunway.com/shop/designers/al...  0.000096
# https://www.renttherunway.com/shop/designers/al...  0.464545
# https://www.renttherunway.com/shop/designers/ba...  0.000126
# https://www.renttherunway.com/shop/designers/ba...  0.000076
# https://www.renttherunway.com/shop/designers/ba...  0.000775
# https://www.renttherunway.com/shop/designers/ba...  0.003644
# https://www.renttherunway.com/shop/designers/ba...  0.000727
# https://www.renttherunway.com/shop/designers/ba...  0.000011
# https://www.renttherunway.com/shop/designers/ba...  0.001017
# https://www.renttherunway.com/shop/designers/ba...  0.000240

# %%
mapping
# Out:
# {'back': {'col_range': 0.89583333333333337, 'min': -0.39583333333333337},
#  'bra': {'col_range': 0.42010582010582009, 'min': 0.0},
#  'color': {'col_range': 0.80833333333333346, 'min': -0.083333333333333329},
#  'material': {'col_range': 0.99041666666666661, 'min': -0.07166666666666667},
#  'pockets': {'col_range': 0.027574314277116586, 'min': 0.0},
#  'sequins_polar': {'col_range': 0.7414783950617283,
#   'min': -0.15131172839506174},
#  'sequins_unpolar': {'col_range': 0.013589843511914119, 'min': 0.0},
#  'wedding': {'col_range': 0.010429103797054551, 'min': 0.00012572456065779416}}

# %% [markdown]
# <a id='walkthrough'></a>
# ## Recommendation Walkthrough
# 1. User inputs body information.
# 2. Assign user to a cluster.
# 3. Ranks dress from 1 to 10.
# 4. Get user's preferences.
# 5. Take the columns that users care about, and assign 1.

# %%
cluster_model = pickle.load(open('../tools/clustering_model.sav', 'rb'))
cluster_mapping = pickle.load(open('../data/cluster_mapping.pkl', 'rb'))

# %%
df_body = df_body.replace(np.nan, 0)

# %% [markdown]
# <a id="findingCluster"></a>
# #### Finding cluster

# %%
num_cols = ['age', 'usually_wears', 'pregnant', 'weight', 'upper_bust', 'under_bust', 'height_in']
def cluster(age=None, usually_wears=None, pregnant=None, weight=None, upper_bust=None, under_bust=None, height=None, body_type=None):
    body_info = np.array([age, usually_wears, pregnant, weight, upper_bust, under_bust, height])
    norm_vals = []
    for col, val in zip(num_cols, body_info):
        mapping = cluster_mapping[col]
        if not val:
            normed = 0.5
        else:
            normed = (val - mapping['min'] ) / mapping['col_range']
        if 'weight' in mapping:
            normed = normed * mapping['weight']
        norm_vals.append(normed)
    
    body_type_array = np.zeros(6) 
    if body_type >= 0:
        body_type_array[body_type] = 1
    input = np.append(norm_vals, body_type_array)
    return cluster_model.predict(input)[0]

# %% [markdown]
# <a id="combination"></a>
# #### Combining general and body specific recommender

# %%
def get_dress_weights(cluster):  
    return df_body[df_body.index==cluster].transpose()

# %%
def get_general_df(df, columns):
    cur_df = df.iloc[:, columns]
    cur_df['dist'] = pairwise_distances(cur_df, [1] * len(columns))
    return cur_df

# %%
def get_recommendations(cluster, columns, n):
    df_cur = get_dress_weights(cluster)
    df_gen = get_general_df(df_norm, columns)
    main_df = df_cur.join(df_gen)
    # boost the good ones
    main_df.loc[main_df[cluster] > 1, 'dist'] -= .1
    # remove negatives
    main_df = main_df[main_df[cluster] > 0] 
    
    rec = []
    for url in main_df.sort_values('dist').head(n).index:
        dress = dress_col.find_one({'url': url})
        rec.append((dress['dress_name'], dress['designer_name'], dress['img_link'], url))
    return rec

# %%
df_norm.to_csv('../data/dress_features_norm.csv')

# %%
pickle.dump(df_norm.columns, open('../data/pref_columns.pkl', 'wb'))

# %% [markdown]
# TODO:
#     - recommend size
#         - find the person with closest point, and see what size they wore

# %%
df_problems = pd.read_csv('../data/dress_problems.csv', index_col=0)
threshold = ["Some customers reported ", "A lot of customers reported "]
problems = ['zipper issues', "dress is too long", 
            'that the dress is itchy', "they have trouble with bra selection", 
            "dress is too short", "the cut is too low"]

# %%
df_problems
# Out:
#                                                       zipper  too_long  \
# url
# https://www.renttherunway.com/shop/designers/al...  0.011290  0.129080
# https://www.renttherunway.com/shop/designers/al...  0.000000  0.177463
# https://www.renttherunway.com/shop/designers/ba...  0.008114  0.206439
# https://www.renttherunway.com/shop/designers/ba...  0.013579  0.183535
# https://www.renttherunway.com/shop/designers/ba...  0.000000  0.011418
# https://www.renttherunway.com/shop/designers/ba...  0.197079  0.074121
# https://www.renttherunway.com/shop/designers/ba...  0.056017  0.197929
# https://www.renttherunway.com/shop/designers/ba...  0.144610  0.109341
# https://www.renttherunway.com/shop/designers/ba...  0.135512  0.231382
# https://www.renttherunway.com/shop/designers/ba...  0.100151  0.175869
# https://www.renttherunway.com/shop/designers/ba...  0.000000  0.718105
# https://www.renttherunway.com/shop/designers/ba...  0.051491  0.002127
# https://www.renttherunway.com/shop/designers/ba...  0.010747  0.754762
# https://www.renttherunway.com/shop/designers/ba...  0.098333  0.310563
# https://www.renttherunway.com/shop/designers/ba...  0.000000  0.719545
# https://www.renttherunway.com/shop/designers/ba...  0.313713  0.292337
# https://www.renttherunway.com/shop/designers/ba...  0.000000  0.181903
# https://www.renttherunway.com/shop/designers/ba...  0.000000  0.403192
# https://www.renttherunway.com/shop/designers/ba...  0.015814  0.190070
# https://www.renttherunway.com/shop/designers/bc...  0.021674  0.027859
# https://www.renttherunway.com/shop/designers/ca...  0.000000  0.000000
# https://www.renttherunway.com/shop/designers/ca...  0.844971  0.323653
# https://www.renttherunway.com/shop/designers/cu...  0.000000  0.000000
# https://www.renttherunway.com/shop/designers/cu...  0.000000  0.316252
# https://www.renttherunway.com/shop/designers/di...  0.000000  0.086433
# https://www.renttherunway.com/shop/designers/dr...  0.000000  0.001951
# https://www.renttherunway.com/shop/designers/ds...  0.000000  0.000000
# https://www.renttherunway.com/shop/designers/el...  0.000000  0.000000
# https://www.renttherunway.com/shop/designers/el...  1.000000  0.000000
# https://www.renttherunway.com/shop/designers/el...  0.230916  0.567461
# ...                                                      ...       ...
# https://www.renttherunway.com/shop/designers/ni...  0.151901  1.000000
# https://www.renttherunway.com/shop/designers/ni...  0.000000  0.000000
# https://www.renttherunway.com/shop/designers/ni...  0.008019  0.003901
# https://www.renttherunway.com/shop/designers/ni...  0.000000  0.190141
# https://www.renttherunway.com/shop/designers/ni...  0.000000  0.000000
# https://www.renttherunway.com/shop/designers/ni...  0.048514  0.651713
# https://www.renttherunway.com/shop/designers/ni...  0.056194  0.179407
# https://www.renttherunway.com/shop/designers/ni...  0.064098  0.000000
# https://www.renttherunway.com/shop/designers/pa...  0.000000  0.000000
# https://www.renttherunway.com/shop/designers/pa...  0.000000  0.002210
# https://www.renttherunway.com/shop/designers/rv...  0.015953  0.063625
# https://www.renttherunway.com/shop/designers/sh...  0.000000  0.000000
# https://www.renttherunway.com/shop/designers/sh...  0.000000  0.136474
# https://www.renttherunway.com/shop/designers/sl...  0.274441  0.031500
# https://www.renttherunway.com/shop/designers/sl...  0.000000  0.127971
# https://www.renttherunway.com/shop/designers/sl...  0.019654  0.019155
# https://www.renttherunway.com/shop/designers/sl...  0.177494  0.071577
# https://www.renttherunway.com/shop/designers/sl...  0.206924  0.958294
# https://www.renttherunway.com/shop/designers/sl...  0.000000  0.000000
# https://www.renttherunway.com/shop/designers/sl...  0.035823  0.003073
# https://www.renttherunway.com/shop/designers/sl...  0.011123  0.013424
# https://www.renttherunway.com/shop/designers/sl...  0.311437  0.224761
# https://www.renttherunway.com/shop/designers/so...  0.133223  0.000000
# https://www.renttherunway.com/shop/designers/th...  0.000000  0.163687
# https://www.renttherunway.com/shop/designers/th...  0.000000  0.210447
# https://www.renttherunway.com/shop/designers/th...  0.000000  0.343977
# https://www.renttherunway.com/shop/designers/th...  0.000000  0.041117
# https://www.renttherunway.com/shop/designers/th...  0.000000  0.157397
# https://www.renttherunway.com/shop/designers/th...  0.000000  0.000000
# https://www.renttherunway.com/shop/designers/tr...  0.000000  0.000000
#
#                                                     sequins_prob  bra_prob  \
# url
# https://www.renttherunway.com/shop/designers/al...      0.000000  0.026477
# https://www.renttherunway.com/shop/designers/al...      0.000000  0.428425
# https://www.renttherunway.com/shop/designers/ba...      0.253180  0.301359
# https://www.renttherunway.com/shop/designers/ba...      0.000000  0.267522
# https://www.renttherunway.com/shop/designers/ba...      0.709521  0.051803
# https://www.renttherunway.com/shop/designers/ba...      0.371657  0.155988
# https://www.renttherunway.com/shop/designers/ba...      0.000000  0.084254
# https://www.renttherunway.com/shop/designers/ba...      0.164791  0.191661
# https://www.renttherunway.com/shop/designers/ba...      0.223710  0.208167
# https://www.renttherunway.com/shop/designers/ba...      0.319006  0.145772
# https://www.renttherunway.com/shop/designers/ba...      0.000000  0.250770
# https://www.renttherunway.com/shop/designers/ba...      1.000000  0.169870
# https://www.renttherunway.com/shop/designers/ba...      0.000000  0.193112
# https://www.renttherunway.com/shop/designers/ba...      0.047561  0.084911
# https://www.renttherunway.com/shop/designers/ba...      0.000000  0.000000
# https://www.renttherunway.com/shop/designers/ba...      0.000222  0.240498
# https://www.renttherunway.com/shop/designers/ba...      0.662394  0.058902
# https://www.renttherunway.com/shop/designers/ba...      0.000000  0.328726
# https://www.renttherunway.com/shop/designers/ba...      0.000000  0.126507
# https://www.renttherunway.com/shop/designers/bc...      0.795209  0.018128
# https://www.renttherunway.com/shop/designers/ca...      0.000000  0.000000
# https://www.renttherunway.com/shop/designers/ca...      0.000000  0.059617
# https://www.renttherunway.com/shop/designers/cu...      0.000000  0.106618
# https://www.renttherunway.com/shop/designers/cu...      0.000000  0.492168
# https://www.renttherunway.com/shop/designers/di...      0.000000  0.000000
# https://www.renttherunway.com/shop/designers/dr...      0.003271  0.000000
# https://www.renttherunway.com/shop/designers/ds...      0.000000  0.176589
# https://www.renttherunway.com/shop/designers/el...      0.000000  0.000000
# https://www.renttherunway.com/shop/designers/el...      0.000000  0.000000
# https://www.renttherunway.com/shop/designers/el...      0.000000  0.044547
# ...                                                          ...       ...
# https://www.renttherunway.com/shop/designers/ni...      0.000000  0.000000
# https://www.renttherunway.com/shop/designers/ni...      0.000000  0.000000
# https://www.renttherunway.com/shop/designers/ni...      0.000000  1.000000
# https://www.renttherunway.com/shop/designers/ni...      0.000000  0.000000
# https://www.renttherunway.com/shop/designers/ni...      0.000000  0.000000
# https://www.renttherunway.com/shop/designers/ni...      0.000000  0.237815
# https://www.renttherunway.com/shop/designers/ni...      0.000098  0.233508
# https://www.renttherunway.com/shop/designers/ni...      0.000000  0.000000
# https://www.renttherunway.com/shop/designers/pa...      0.000000  0.180296
# https://www.renttherunway.com/shop/designers/pa...      0.000000  0.164603
# https://www.renttherunway.com/shop/designers/rv...      0.000000  0.000000
# https://www.renttherunway.com/shop/designers/sh...      0.000000  0.000000
# https://www.renttherunway.com/shop/designers/sh...      0.000000  0.383680
# https://www.renttherunway.com/shop/designers/sl...      0.000000  0.417653
# https://www.renttherunway.com/shop/designers/sl...      0.085148  0.270096
# https://www.renttherunway.com/shop/designers/sl...      0.507598  0.053939
# https://www.renttherunway.com/shop/designers/sl...      0.000000  0.192046
# https://www.renttherunway.com/shop/designers/sl...      0.000000  0.858592
# https://www.renttherunway.com/shop/designers/sl...      0.000000  0.000000
# https://www.renttherunway.com/shop/designers/sl...      0.465042  0.034075
# https://www.renttherunway.com/shop/designers/sl...      0.329183  0.322463
# https://www.renttherunway.com/shop/designers/sl...      0.000000  0.000000
# https://www.renttherunway.com/shop/designers/so...      0.000000  0.000000
# https://www.renttherunway.com/shop/designers/th...      0.000000  0.686217
# https://www.renttherunway.com/shop/designers/th...      0.000600  0.142606
# https://www.renttherunway.com/shop/designers/th...      0.000000  0.204099
# https://www.renttherunway.com/shop/designers/th...      0.000000  0.516455
# https://www.renttherunway.com/shop/designers/th...      0.000000  0.000000
# https://www.renttherunway.com/shop/designers/th...      0.000000  0.000000
# https://www.renttherunway.com/shop/designers/tr...      0.000000  0.000000
#
#                                                     too_short   low_cut
# url
# https://www.renttherunway.com/shop/designers/al...   0.050237  0.000000
# https://www.renttherunway.com/shop/designers/al...   0.020011  1.000000
# https://www.renttherunway.com/shop/designers/ba...   0.081946  0.111259
# https://www.renttherunway.com/shop/designers/ba...   0.073729  0.000000
# https://www.renttherunway.com/shop/designers/ba...   0.013316  0.000000
# https://www.renttherunway.com/shop/designers/ba...   0.041886  0.308847
# https://www.renttherunway.com/shop/designers/ba...   0.185002  0.025782
# https://www.renttherunway.com/shop/designers/ba...   0.041623  0.093729
# https://www.renttherunway.com/shop/designers/ba...   0.041926  0.371702
# https://www.renttherunway.com/shop/designers/ba...   0.064242  0.051973
# https://www.renttherunway.com/shop/designers/ba...   0.000000  0.000000
# https://www.renttherunway.com/shop/designers/ba...   0.038324  0.326968
# https://www.renttherunway.com/shop/designers/ba...   0.043520  0.060233
# https://www.renttherunway.com/shop/designers/ba...   0.030986  0.000000
# https://www.renttherunway.com/shop/designers/ba...   0.044910  0.121487
# https://www.renttherunway.com/shop/designers/ba...   0.051669  0.016551
# https://www.renttherunway.com/shop/designers/ba...   0.008079  0.000000
# https://www.renttherunway.com/shop/designers/ba...   0.087897  0.000000
# https://www.renttherunway.com/shop/designers/ba...   0.143833  0.000846
# https://www.renttherunway.com/shop/designers/bc...   0.047023  0.000000
# https://www.renttherunway.com/shop/designers/ca...   0.000000  0.000000
# https://www.renttherunway.com/shop/designers/ca...   0.015118  0.000000
# https://www.renttherunway.com/shop/designers/cu...   0.148051  0.000000
# https://www.renttherunway.com/shop/designers/cu...   0.065801  0.000000
# https://www.renttherunway.com/shop/designers/di...   0.081577  0.000000
# https://www.renttherunway.com/shop/designers/dr...   0.393521  0.000000
# https://www.renttherunway.com/shop/designers/ds...   0.000000  0.000000
# https://www.renttherunway.com/shop/designers/el...   0.000000  0.000000
# https://www.renttherunway.com/shop/designers/el...   0.000000  0.000000
# https://www.renttherunway.com/shop/designers/el...   0.024059  0.081191
# ...                                                       ...       ...
# https://www.renttherunway.com/shop/designers/ni...   0.000000  0.000000
# https://www.renttherunway.com/shop/designers/ni...   1.000000  0.000000
# https://www.renttherunway.com/shop/designers/ni...   0.015540  0.519796
# https://www.renttherunway.com/shop/designers/ni...   0.000000  0.000000
# https://www.renttherunway.com/shop/designers/ni...   0.000000  0.000000
# https://www.renttherunway.com/shop/designers/ni...   0.056596  0.124454
# https://www.renttherunway.com/shop/designers/ni...   0.043912  0.123999
# https://www.renttherunway.com/shop/designers/ni...   0.090754  0.000000
# https://www.renttherunway.com/shop/designers/pa...   0.000000  0.006412
# https://www.renttherunway.com/shop/designers/pa...   0.000000  0.193842
# https://www.renttherunway.com/shop/designers/rv...   0.003816  0.039720
# https://www.renttherunway.com/shop/designers/sh...   0.000000  0.000000
# https://www.renttherunway.com/shop/designers/sh...   0.066331  0.000000
# https://www.renttherunway.com/shop/designers/sl...   0.031179  0.000000
# https://www.renttherunway.com/shop/designers/sl...   0.070239  0.020183
# https://www.renttherunway.com/shop/designers/sl...   0.155765  0.015599
# https://www.renttherunway.com/shop/designers/sl...   0.157012  0.016150
# https://www.renttherunway.com/shop/designers/sl...   0.031022  0.460213
# https://www.renttherunway.com/shop/designers/sl...   0.000000  0.000000
# https://www.renttherunway.com/shop/designers/sl...   0.063502  0.054507
# https://www.renttherunway.com/shop/designers/sl...   0.071809  0.330992
# https://www.renttherunway.com/shop/designers/sl...   0.011063  0.000000
# https://www.renttherunway.com/shop/designers/so...   0.000000  0.000000
# https://www.renttherunway.com/shop/designers/th...   0.048716  0.005490
# https://www.renttherunway.com/shop/designers/th...   0.026828  0.000000
# https://www.renttherunway.com/shop/designers/th...   0.089571  0.008431
# https://www.renttherunway.com/shop/designers/th...   0.085388  0.037864
# https://www.renttherunway.com/shop/designers/th...   0.015098  0.000000
# https://www.renttherunway.com/shop/designers/th...   0.000000  0.000000
# https://www.renttherunway.com/shop/designers/tr...   0.506949  0.000000
#
# [90 rows x 6 columns]

# %%
def get_problems(url, bottom_threshold=0.1, high_threshold=0.5):
    problem_list = []
    for i, val in enumerate(df_problems[df_problems.index == url].values[0]):
        print(val)
        if val > high_threshold:
            problem_list.append(threshold[0] + problems[i])
        elif val > bottom_threshold:
            problem_list.append(threshold[1] + problems[i])
    return problem_list

# %%
df_problems = df_problems.drop('bra', axis=1)

# %%
df_problems.to_csv('../data/dress_problems.csv')
